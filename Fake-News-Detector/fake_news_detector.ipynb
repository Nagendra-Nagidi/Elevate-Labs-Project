# %%
import pandas as pd
import numpy as np

# %%
true=pd.read_csv('data/True.csv')

# %%
fake=pd.read_csv('data/Fake.csv')

# %%
true.head()
# Out:
#                                                title  \
# 0  As U.S. budget fight looms, Republicans flip t...
# 1  U.S. military to accept transgender recruits o...
# 2  Senior U.S. Republican senator: 'Let Mr. Muell...
# 3  FBI Russia probe helped by Australian diplomat...
# 4  Trump wants Postal Service to charge 'much mor...
#
#                                                 text       subject  \
# 0  WASHINGTON (Reuters) - The head of a conservat...  politicsNews
# 1  WASHINGTON (Reuters) - Transgender people will...  politicsNews
# 2  WASHINGTON (Reuters) - The special counsel inv...  politicsNews
# 3  WASHINGTON (Reuters) - Trump campaign adviser ...  politicsNews
# 4  SEATTLE/WASHINGTON (Reuters) - President Donal...  politicsNews
#
#                  date
# 0  December 31, 2017
# 1  December 29, 2017
# 2  December 31, 2017
# 3  December 30, 2017
# 4  December 29, 2017

# %%
fake.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date
# 0  December 31, 2017
# 1  December 31, 2017
# 2  December 30, 2017
# 3  December 29, 2017
# 4  December 25, 2017

# %%
true['label']=1
fake['label']=0

# %%
news = pd.concat([fake, true], axis=0)

# %%
news.head()
# Out:
#                                                title  \
# 0   Donald Trump Sends Out Embarrassing New Year’...
# 1   Drunk Bragging Trump Staffer Started Russian ...
# 2   Sheriff David Clarke Becomes An Internet Joke...
# 3   Trump Is So Obsessed He Even Has Obama’s Name...
# 4   Pope Francis Just Called Out Donald Trump Dur...
#
#                                                 text subject  \
# 0  Donald Trump just couldn t wish all Americans ...    News
# 1  House Intelligence Committee Chairman Devin Nu...    News
# 2  On Friday, it was revealed that former Milwauk...    News
# 3  On Christmas day, Donald Trump announced that ...    News
# 4  Pope Francis used his annual Christmas Day mes...    News
#
#                 date  label
# 0  December 31, 2017      0
# 1  December 31, 2017      0
# 2  December 30, 2017      0
# 3  December 29, 2017      0
# 4  December 25, 2017      0

# %%
news.tail()
# Out:
#                                                    title  \
# 21412  'Fully committed' NATO backs new U.S. approach...
# 21413  LexisNexis withdrew two products from Chinese ...
# 21414  Minsk cultural hub becomes haven from authorities
# 21415  Vatican upbeat on possibility of Pope Francis ...
# 21416  Indonesia to buy $1.14 billion worth of Russia...
#
#                                                     text    subject  \
# 21412  BRUSSELS (Reuters) - NATO allies on Tuesday we...  worldnews
# 21413  LONDON (Reuters) - LexisNexis, a provider of l...  worldnews
# 21414  MINSK (Reuters) - In the shadow of disused Sov...  worldnews
# 21415  MOSCOW (Reuters) - Vatican Secretary of State ...  worldnews
# 21416  JAKARTA (Reuters) - Indonesia will buy 11 Sukh...  worldnews
#
#                    date  label
# 21412  August 22, 2017       1
# 21413  August 22, 2017       1
# 21414  August 22, 2017       1
# 21415  August 22, 2017       1
# 21416  August 22, 2017       1

# %%
news.isnull().sum()
# Out:
# title      0
# text       0
# subject    0
# date       0
# label      0
# dtype: int64

# %%
news=news.drop(['title','subject','date'],axis=1)

# %%
news.head()
# Out:
#                                                 text  label
# 0  Donald Trump just couldn t wish all Americans ...      0
# 1  House Intelligence Committee Chairman Devin Nu...      0
# 2  On Friday, it was revealed that former Milwauk...      0
# 3  On Christmas day, Donald Trump announced that ...      0
# 4  Pope Francis used his annual Christmas Day mes...      0

# %%
#reshufling
news=news.sample(frac=1)

# %%
news.reset_index(inplace=True)

# %%
news=news.drop(['index'],axis=1)

# %%
news.head()
# Out:
#                                                 text  label
# 0  LAGOS (Reuters) - Lawmakers in the upper house...      1
# 1  It s amazing the sheep mentality of students a...      0
# 2  WASHINGTON (Reuters) - The White House said on...      1
# 3  WASHINGTON/SEOUL (Reuters) - Images released b...      1
# 4  WASHINGTON (Reuters) - President Barack Obama’...      1

# %%
import re

# %%
def wordopt(text):
    #convert to lowercase
    text=text.lower()

    #remove Urls
    text=re.sub(r'https?://\S+|www\.\S+', '', text)

    #remove Html tags
    text=re.sub(r'<.*?>', '', text)

    #remove punctuation
    text=re.sub(r'[^\w\s]', '', text)

    #remove digits
    text=re.sub(r'\d+', '', text)

    #remove newline characters
    text=re.sub(r'\n', ' ', text)
    
    return text

# %%
news['text']=news['text'].apply(wordopt)

# %%
news
# Out:
#                                                     text  label
# 0      lagos reuters  lawmakers in the upper house of...      1
# 1      it s amazing the sheep mentality of students a...      0
# 2      washington reuters  the white house said on tu...      1
# 3      washingtonseoul reuters  images released by no...      1
# 4      washington reuters  president barack obamas vi...      1
# ...                                                  ...    ...
# 44893  if this had been a tea party group attacking n...      0
# 44894  the hosts of fox  friends were hoping a minnes...      0
# 44895  washington reuters  two senior republican lawm...      1
# 44896  reuters  democratic us senator edward markey o...      1
# 44897  st century wire says in a tweet by president d...      0
#
# [44898 rows x 2 columns]

# %%
X=news['text']

# %%
y=news['label']

# %%
X
# Out:
# 0        lagos reuters  lawmakers in the upper house of...
# 1        it s amazing the sheep mentality of students a...
# 2        washington reuters  the white house said on tu...
# 3        washingtonseoul reuters  images released by no...
# 4        washington reuters  president barack obamas vi...
#                                ...
# 44893    if this had been a tea party group attacking n...
# 44894    the hosts of fox  friends were hoping a minnes...
# 44895    washington reuters  two senior republican lawm...
# 44896    reuters  democratic us senator edward markey o...
# 44897    st century wire says in a tweet by president d...
# Name: text, Length: 44898, dtype: object

# %%
y
# Out:
# 0        1
# 1        0
# 2        1
# 3        1
# 4        1
#         ..
# 44893    0
# 44894    0
# 44895    1
# 44896    1
# 44897    0
# Name: label, Length: 44898, dtype: int64

# %%
from sklearn.model_selection import train_test_split

# %%
X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3)

# %%
X_train.shape, X_test.shape, y_train.shape, y_test.shape
# Out:
# ((31428,), (13470,), (31428,), (13470,))

# %%
# Vectorization
from sklearn.feature_extraction.text import TfidfVectorizer

# %%
vectorizer = TfidfVectorizer()

# %%
xv_train = vectorizer.fit_transform(X_train)

# %%
xv_test = vectorizer.transform(X_test)

# %%
xv_train
# Out:
# <31428x174536 sparse matrix of type '<class 'numpy.float64'>'
# 	with 6437746 stored elements in Compressed Sparse Row format>

# %%
xv_test
# Out:
# <13470x174536 sparse matrix of type '<class 'numpy.float64'>'
# 	with 2741900 stored elements in Compressed Sparse Row format>

# %%
#Training the model
from sklearn.linear_model import LogisticRegression

# %%
LR = LogisticRegression()

# %%
LR.fit(xv_train, y_train)
# Out:
# LogisticRegression()

# %%
y_pred = LR.predict(xv_test)

# %%
#Validation
from sklearn.metrics import classification_report

# %%
LR.score(xv_test, y_test)
# Out:
# 0.9876020786933927

# %%
print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.99      0.99      0.99      7058
#            1       0.98      0.99      0.99      6412
#
#     accuracy                           0.99     13470
#    macro avg       0.99      0.99      0.99     13470
# weighted avg       0.99      0.99      0.99     13470

# %%
import joblib
joblib.dump(vectorizer, 'vectorizer.jb')
joblib.dump(LR,'lr_model.jb')
# Out:
# ['lr_model.jb']
